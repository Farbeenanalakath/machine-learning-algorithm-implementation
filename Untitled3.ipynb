# %%
import pandas as pd
data=pd.read_csv("Women.csv")

# %%
data
# Out:
#                 India/States/UTs  Survey   Area  \
# 0    Andaman and Nicobar Islands  NFHS-3  Total
# 1    Andaman and Nicobar Islands  NFHS-4  Total
# 2    Andaman and Nicobar Islands  NFHS-4  Rural
# 3    Andaman and Nicobar Islands  NFHS-4  Urban
# 4                 Andhra Pradesh  NFHS-3  Total
# ..                           ...     ...    ...
# 143                    Telangana  NFHS-4  Urban
# 144                      Tripura  NFHS-4  Urban
# 145                Uttar Pradesh  NFHS-4  Urban
# 146                  Uttarakhand  NFHS-4  Urban
# 147                  West Bengal  NFHS-4  Urban
#
#      Population and Household Profile - Population (female) age 6 years and above who ever attended school (%)  \
# 0                                                  NaN
# 1                                                 84.7
# 2                                                 82.6
# 3                                                 87.6
# ...
