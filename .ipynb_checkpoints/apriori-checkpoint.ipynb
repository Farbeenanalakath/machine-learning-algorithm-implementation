# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori,association_rules

# %%
data=pd.read_csv("OnlineRetail.csv~.zip",encoding='unicode_escape')

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data['InvoiceNo']=data['InvoiceNo'].astype('str')

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data=data[~data['InvoiceNo'].str.contains('c')]

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
basket_France=(data[data['Country']=="France"].groupby(["InvoiceNo","Description"]))

# %%
basket_France

# %%
for i,j in basket_France:
    print(i)
    print(j)
# Out:
# Quantity
#  50'S CHRISTMAS GIFT BAG LARGE
# Quantity
#  DOLLY GIRL BEAKER
# Quantity
#  I LOVE LONDON MINI BACKPACK
# Quantity
#  NINE DRAWER OFFICE TIDY
# Quantity
#  SET 2 TEA TOWELS I LOVE LONDON
# Quantity
#  SPACEBOY BABY GIFT SET
# Quantity
#  TRELLIS COAT RACK
# Quantity
# 10 COLOUR SPACEBOY PEN
# Quantity
# 12 COLOURED PARTY BALLOONS
# Quantity
# 12 EGG HOUSE PAINTED WOOD
# Quantity
# 12 MESSAGE CARDS WITH ENVELOPES
# Quantity
# 12 PENCIL SMALL TUBE WOODLAND
# Quantity
# 12 PENCILS SMALL TUBE RED RETROSPOT
# Quantity
# 12 PENCILS SMALL TUBE SKULL
# Quantity
# 12 PENCILS TALL TUBE POSY
# Quantity
# 12 PENCILS TALL TUBE RED RETROSPOT
# Quantity
# 12 PENCILS TALL TUBE WOODLAND
# Quantity
# 15CM CHRISTMAS GLASS BALL 20 LIGHTS
# Quantity
# 16 PIECE CUTLERY SET PANTRY DESIGN
# Quantity
# 18PC WOODEN CUTLERY SET DISPOSABLE
# Quantity
# 20 DOLLY PEGS RETROSPOT
# Quantity
# 200 RED + WHITE BENDY STRAWS
# Quantity
# 3 HOOK HANGER MAGIC GARDEN
# Quantity
# ...

# %%
basket_France=(data[data['Country']=="France"].groupby(["InvoiceNo","Description"])).sum().unstack().reset_index().fillna(0).set_index("InvoiceNo")

# %%
basket_France
# Out:
#                                   Quantity                     \
# Description  50'S CHRISTMAS GIFT BAG LARGE  DOLLY GIRL BEAKER
# InvoiceNo
# 536370                                 0.0                0.0
# 536852                                 0.0                0.0
# 536974                                 0.0                0.0
# 537065                                 0.0                0.0
# 537463                                 0.0                0.0
# ...                                    ...                ...
# C579532                                0.0                0.0
# C579562                                0.0                0.0
# C580161                                0.0                0.0
# C580263                                0.0                0.0
# C581316                                0.0                0.0
#
#                                                                    \
# Description  I LOVE LONDON MINI BACKPACK  NINE DRAWER OFFICE TIDY
# InvoiceNo
# ...

# %%
basket_Por=(data[data['Country']=="Portugal"]
            .groupby(["InvoiceNo","Description"])).sum().unstack().reset_index().fillna(0)
            .set_index("InvoiceNo")

# %%
basket_Sweden=(data[data['Country']=="Sweden"].groupby(["InvoiceNo","Description"])).sum().unstack().reset_index().fillna(0).set_index("InvoiceNo")

# %%
basket_UK=(data[data['Country']=="UK"].groupby(["InvoiceNo","Description"])).sum().unstack().reset_index().fillna(0).set_index("InvoiceNo")

# %%
def hot_encode(x):
    if(x<=0):
        return 0
    if(x>=1):
        return 1

# %%
basket_encoded=basket_France.applymap(hot_encode)
basket_France=basket_encoded

# %%
basket_encoded
# Out:
#                                   Quantity                     \
# Description  50'S CHRISTMAS GIFT BAG LARGE  DOLLY GIRL BEAKER
# InvoiceNo
# 536370                                   0                  0
# 536852                                   0                  0
# 536974                                   0                  0
# 537065                                   0                  0
# 537463                                   0                  0
# ...                                    ...                ...
# C579532                                  0                  0
# C579562                                  0                  0
# C580161                                  0                  0
# C580263                                  0                  0
# C581316                                  0                  0
#
#                                                                    \
# Description  I LOVE LONDON MINI BACKPACK  NINE DRAWER OFFICE TIDY
# InvoiceNo
# ...

# %%
basket_encoded=basket_UK.applymap(hot_encode)
basket_UK=basket_encoded
basket_encoded=basket_Por.applymap(hot_encode)
basket_Por=basket_encoded
basket_encoded=basket_Sweden.applymap(hot_encode)
basket_Sweden=basket_encoded
